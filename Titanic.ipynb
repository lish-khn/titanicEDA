# %% [markdown]
# # Titanic dataset EDA

# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\FUJITSU\OneDrive\Desktop\Data analysis\tit.CSV")

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
sns.pairplot(df,hue="survived")

# %%
df['age'].fillna(df['age'].median())
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305    28.0000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
df['age'].fillna(df['age'].median())
df['embarked'].fillna(df['embarked'].mode()[0])
# Out:
# 0       S
# 1       S
# 2       S
# 3       S
# 4       S
#        ..
# 1304    C
# 1305    C
# 1306    C
# 1307    C
# 1308    S
# Name: embarked, Length: 1309, dtype: object

# %% [markdown]
# # Univariate analysis

# %%
sns.countplot(x='survived', data=df, palette='viridis').set_title('survived')
# Out:
# Text(0.5, 1.0, 'survived')

# %%
sns.histplot(df['age']).set_title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %% [markdown]
# # Bivariate analysis

# %%
sns.barplot(x='sex',y='survived',data=df,palette='coolwarm').set_title('Survived')
# Out:
# Text(0.5, 1.0, 'Survived')

# %%
sns.boxplot(x='pclass', y='age', data=df, palette='muted').set_title('Age Distribution by Passenger Class')
# Out:
# Text(0.5, 1.0, 'Age Distribution by Passenger Class')

# %% [markdown]
# # Correlation heatmap

# %%
data = df[['pclass','survived','age','sibsp','parch','fare']]

# %%
sns.heatmap(data.corr(), annot=True, cmap='PiYG', fmt='.2f').set_title("Feature Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Feature Correlation Heatmap')

# %% [markdown]
# Women had a significantly higher survival rate than men
# Passengers from higher classes (Pclass 1) had a better survival chance
# Younger passengers had a higher survival rate
# The heatmap showed correlations, with Pclass being strong predictors of survival

# %% [markdown]
# # EDA Completed successfully!
